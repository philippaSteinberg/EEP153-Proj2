# %% [markdown]
# # function to solve subsistence problem

# %%
from  scipy.optimize import linprog as lp
import numpy as np
import warnings

def solve_subsistence_problem(FoodNutrients,Prices,dietmin,dietmax,max_weight=None,tol=1e-6):
    """Solve Stigler's Subsistence Cost Problem.

    Inputs:
       - FoodNutrients : A pd.DataFrame with rows corresponding to foods, columns to nutrients.
       - Prices : A pd.Series of prices for different foods
       - diet_min : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing minimum intakes.
       - diet_max : A pd.Series of DRIs, with index corresponding to columns of FoodNutrients,
                    describing maximum intakes.
       - max_weight : Maximum weight (in hectograms) allowed for diet.
       - tol : Solution values smaller than this in absolute value treated as zeros.
       
    """
    try: 
        p = Prices.apply(lambda x:x.magnitude)
    except AttributeError:  # Maybe not passing in prices with units?
        warnings.warn("Prices have no units.  BE CAREFUL!  We're assuming prices are per hectogram or deciliter!")
        p = Prices

    p = p.dropna()

    # Compile list that we have both prices and nutritional info for; drop if either missing
    use = p.index.intersection(FoodNutrients.columns)
    p = p[use]

    # Drop nutritional information for foods we don't know the price of,
    # and replace missing nutrients with zeros.
    Aall = FoodNutrients[p.index].fillna(0)

    # Drop rows of A that we don't have constraints for.
    Amin = Aall.loc[Aall.index.intersection(dietmin.index)]
    Amin = Amin.reindex(dietmin.index,axis=0)
    idx = Amin.index.to_frame()
    idx['type'] = 'min'
    #Amin.index = pd.MultiIndex.from_frame(idx)
    #dietmin.index = Amin.index
    
    Amax = Aall.loc[Aall.index.intersection(dietmax.index)]
    Amax = Amax.reindex(dietmax.index,axis=0)
    idx = Amax.index.to_frame()
    idx['type'] = 'max'
    #Amax.index = pd.MultiIndex.from_frame(idx)
    #dietmax.index = Amax.index

    # Minimum requirements involve multiplying constraint by -1 to make <=.
    A = pd.concat([Amin,
                   -Amax])

    b = pd.concat([dietmin,
                   -dietmax]) # Note sign change for max constraints

    # Make sure order of p, A, b are consistent
    A = A.reindex(p.index,axis=1)
    A = A.reindex(b.index,axis=0)

    if max_weight is not None:
        # Add up weights of foods consumed
        A.loc['Hectograms'] = -1
        b.loc['Hectograms'] = -max_weight
        
    # Now solve problem!  (Note that the linear program solver we'll use assumes
    # "less-than-or-equal" constraints.  We can switch back and forth by
    # multiplying $A$ and $b$ by $-1$.)

    result = lp(p, -A, -b, method='interior-point')

    result.A = A
    result.b = b
    
    if result.success:
        result.diet = pd.Series(result.x,index=p.index)
    else: # No feasible solution?
        warnings.warn(result.message)
        result.diet = pd.Series(result.x,index=p.index)*np.nan  

    return result

# %% [markdown]
# # setup

# %%
#!git reset --hard origin/master  # To revert to original
# !pip install -r requirements.txt --upgrade
# Out:
# Requirement already satisfied: pint>=0.18 in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (0.20.1)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.28.2)
# Requirement already satisfied: python-gnupg in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: eep153_tools in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (0.11)
# Requirement already satisfied: fooddatacentral in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.26.0->-r requirements.txt (line 6)) (3.1)

# %%
api_lst = ["9pWr4Z38nFyytVVF2LPQWJ5G3x5SrVO0Px3MbQOl",
           "bShyCnUYYfY6eP3qyUt6VGY1MqEQklrOeuwPUps5",
           "5EVJteEMrjnX73GRj4Q9qqB3NWqIObFujtP4fBGI",
           "saSE5uqp940Hmw6imfc1FaCo6qFJS9dOH8RIjSJW"
          ]
apikey = api_lst[3]

# %% [markdown]
# # input data

# %% [markdown]
# # compile data on food prices

# %%
import pandas as pd
from eep153_tools.sheets import read_sheets

df = read_sheets("https://docs.google.com/spreadsheets/d/1Ml9KIH_HLl64Y8zTldoghUu5ZhTY7IXanN77itVAxRM/edit#gid=0", 
                sheet='prices')
df
# Out:
# Key available for students@eep153.iam.gserviceaccount.com.
#               Food  Quantity           Units  Price        Date  \
# 0            Bread       1.0         serving   1.33  2023/02/28
# 1           Cheese       8.0              oz   3.49  2023/02/27
# 2      Ground Beef      16.0              oz   4.99  2023/02/27
# 3   cheese burger        1.0  cheese burger    3.01  2023/02/27
# 4      1% fat milk       1.0          gallon   4.39  2023/02/27
# 5        red apple       1.0           pound   0.99  2023/02/28
# 6          edamame       1.0           pound   1.89  2023/02/28
# 7      mini carrot       1.0           pound   1.49  2023/02/28
# 8         mandarin       2.0           pound   3.99  2023/02/27
# 9      cauliflower       2.0           pound   2.99  2023/02/27
# 10    celery stick       NaN                    NaN
# 11      bosc pear        1.0           pound   1.49  2023/02/28
# 12          orange       4.0           pound   4.99  2023/02/27
# 13    jicama stick       NaN                    NaN
# 14        spinach        NaN                    NaN
# 15            kiwi       1.0           pound   1.99  2023/02/28
# 16   bartlett peat       NaN                    NaN
#
#                       Location      FDC
# 0   MI Ranchito Bayside Market  2431121
# 1                 Trader Joe's  2383425
# 2                 Trader Joe's  1662368
# 3                Trader Joe's   2022263
# 4                 Trader Joe's  2340764
# 5   MI Ranchito Bayside Market  1750339
# 6   MI Ranchito Bayside Market  2384458
# 7                       Target  2345173
# 8                 Trader Joe's   169105
# 9                 Trader Joe's  2409200
# 10                              2345298
# 11  MI Ranchito Bayside Market  1662757
# 12                Trader Joe's  1864680
# 13                              2345307
# 14                               721056
# 15  MI Ranchito Bayside Market  1898469
# 16                               746773

# %%
# import fooddatacentral as fdc
# import warnings

# D = {}
# count = 0
# for food in  df.Food.tolist():
#     try:
#         FDC = df.loc[df.Food==food,:].FDC[count]
#         count+=1
#         D[food] = fdc.nutrients(apikey,FDC).Quantity
#     except AttributeError: 
#         warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))        

# FoodNutrients = pd.DataFrame(D,dtype=float)
# Out:
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code Bread for food 2431121.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code Cheese for food 2383425.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code Ground Beef for food 1662368.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code cheese burger  for food 2022263.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code 1% fat milk for food 2340764.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code edamame for food 2384458.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code mini carrot for food 2345173.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code mandarin for food 169105.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code kiwi for food 1898469.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))
# /tmp/ipykernel_134/1532008836.py:12: UserWarning: Couldn't find FDC Code bartlett peat for food 746773.
#   warnings.warn("Couldn't find FDC Code %s for food %s." % (food,FDC))

# %%
FoodNutrients = pd.read_csv("FoodNutrients.csv")
FoodNutrients
# Out:
#                            Unnamed: 0  Bread  Cheese  Ground Beef  \
# 0                             Alanine    NaN     NaN          NaN
# 1                      Alcohol, ethyl    NaN     NaN          NaN
# 2                         Amino acids    NaN     NaN          NaN
# 3                            Arginine    NaN     NaN          NaN
# 4                                 Ash    NaN     NaN          NaN
# ..                                ...    ...     ...          ...
# 113  Vitamin K (Dihydrophylloquinone)    NaN     NaN          NaN
# 114         Vitamin K (phylloquinone)    NaN     NaN          NaN
# 115     Vitamins and Other Components    NaN     NaN          NaN
# 116                             Water    NaN     NaN          NaN
# 117                          Zinc, Zn    NaN     NaN          NaN
#
#      cheese burger   1% fat milk  red apple  edamame  mini carrot  mandarin  \
# 0               NaN          NaN        NaN      NaN          NaN     0.028
# 1               NaN         0.00        NaN      NaN         0.00     0.000
# 2               NaN          NaN        NaN      NaN          NaN     0.000
# 3               NaN          NaN        NaN      NaN          NaN     0.068
# 4               NaN          NaN    0.14830      NaN          NaN     0.380
# ..              ...          ...        ...      ...          ...       ...
# 113             NaN          NaN        NaN      NaN          NaN     0.000
# 114             NaN         0.10        NaN      NaN        13.20     0.000
# 115             NaN          NaN    0.00000      NaN          NaN     0.000
# 116             NaN        89.70   84.67000      NaN        88.30    85.170
# 117             NaN         0.43    0.01964      NaN         0.24     0.070
#
#      cauliflower  celery stick  bosc pear   orange  jicama stick  spinach   \
# 0            NaN           NaN         NaN     NaN           NaN       NaN
# 1            NaN          0.00         NaN     NaN          0.00       NaN
# 2            NaN           NaN         NaN     NaN           NaN       NaN
# 3            NaN           NaN         NaN     NaN           NaN       NaN
# 4            NaN           NaN         NaN     NaN           NaN       NaN
# ..           ...           ...         ...     ...           ...       ...
# 113          NaN           NaN         NaN     NaN           NaN       NaN
# 114          NaN         29.30         NaN     NaN          0.30     483.5
# 115          NaN           NaN         NaN     NaN           NaN       NaN
# 116          NaN         95.40         NaN     NaN         90.10       NaN
# 117          NaN          0.13         NaN     NaN          0.16       NaN
#
#      kiwi  bartlett peat
# 0     NaN          0.016
# 1     NaN            NaN
# 2     NaN          0.000
# 3     NaN          0.012
# 4     NaN          0.300
# ..    ...            ...
# 113   NaN          0.000
# 114   NaN          3.800
# 115   NaN          0.000
# 116   NaN         84.100
# 117   NaN          0.070
#
# [118 rows x 18 columns]

# %%
FoodNutrients.to_pickle('FoodNutrients.pickle')

# %%
FoodNutrients
# Out:
#                            Unnamed: 0  Bread  Cheese  Ground Beef  \
# 0                             Alanine    NaN     NaN          NaN
# 1                      Alcohol, ethyl    NaN     NaN          NaN
# 2                         Amino acids    NaN     NaN          NaN
# 3                            Arginine    NaN     NaN          NaN
# 4                                 Ash    NaN     NaN          NaN
# ..                                ...    ...     ...          ...
# 113  Vitamin K (Dihydrophylloquinone)    NaN     NaN          NaN
# 114         Vitamin K (phylloquinone)    NaN     NaN          NaN
# 115     Vitamins and Other Components    NaN     NaN          NaN
# 116                             Water    NaN     NaN          NaN
# 117                          Zinc, Zn    NaN     NaN          NaN
#
#      cheese burger   1% fat milk  red apple  edamame  mini carrot  mandarin  \
# 0               NaN          NaN        NaN      NaN          NaN     0.028
# 1               NaN         0.00        NaN      NaN         0.00     0.000
# 2               NaN          NaN        NaN      NaN          NaN     0.000
# 3               NaN          NaN        NaN      NaN          NaN     0.068
# 4               NaN          NaN    0.14830      NaN          NaN     0.380
# ..              ...          ...        ...      ...          ...       ...
# 113             NaN          NaN        NaN      NaN          NaN     0.000
# 114             NaN         0.10        NaN      NaN        13.20     0.000
# 115             NaN          NaN    0.00000      NaN          NaN     0.000
# 116             NaN        89.70   84.67000      NaN        88.30    85.170
# 117             NaN         0.43    0.01964      NaN         0.24     0.070
#
#      cauliflower  celery stick  bosc pear   orange  jicama stick  spinach   \
# 0            NaN           NaN         NaN     NaN           NaN       NaN
# 1            NaN          0.00         NaN     NaN          0.00       NaN
# 2            NaN           NaN         NaN     NaN           NaN       NaN
# 3            NaN           NaN         NaN     NaN           NaN       NaN
# 4            NaN           NaN         NaN     NaN           NaN       NaN
# ..           ...           ...         ...     ...           ...       ...
# 113          NaN           NaN         NaN     NaN           NaN       NaN
# 114          NaN         29.30         NaN     NaN          0.30     483.5
# 115          NaN           NaN         NaN     NaN           NaN       NaN
# 116          NaN         95.40         NaN     NaN         90.10       NaN
# 117          NaN          0.13         NaN     NaN          0.16       NaN
#
#      kiwi  bartlett peat
# 0     NaN          0.016
# 1     NaN            NaN
# 2     NaN          0.000
# 3     NaN          0.012
# 4     NaN          0.300
# ..    ...            ...
# 113   NaN          0.000
# 114   NaN          3.800
# 115   NaN          0.000
# 116   NaN         84.100
# 117   NaN          0.070
#
# [118 rows x 18 columns]

# %% [markdown]
# # units & prices

# %%
# Convert food quantities to FDC units
df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
df['FDC Price'] = df['Price']/df['FDC Quantity']

df.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
Prices = df.groupby('Food',sort=False)['FDC Price'].min()
# Out:
# ---------------------------------------------------------------------------
# DimensionalityError                       Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/fooddatacentral/fooddatacentral.py:117, in units(q, u, ureg)
#     116 try:
# --> 117     return x.to(ureg.hectogram)
#     118 except DimensionalityError:
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/quantity.py:522, in PlainQuantity.to(self, other, *contexts, **ctx_kwargs)
#     520 other = to_units_container(other, self._REGISTRY)
# --> 522 magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     524 return self.__class__(magnitude, other)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/quantity.py:471, in PlainQuantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     469         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 471 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/registry.py:911, in PlainRegistry.convert(self, value, src, dst, inplace)
#     909     return value
# --> 911 return self._convert(value, src, dst, inplace)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/context/registry.py:393, in ContextRegistry._convert(self, value, src, dst, inplace)
#     391         value, src = src._magnitude, src._units
# --> 393 return super()._convert(value, src, dst, inplace)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/nonmultiplicative/registry.py:206, in NonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#     205 if not (src_offset_unit or dst_offset_unit):
# --> 206     return super()._convert(value, src, dst, inplace)
#     208 src_dim = self._get_dimensionality(src)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/registry.py:944, in PlainRegistry._convert(self, value, src, dst, inplace, check_dimensionality)
#     943     if src_dim != dst_dim:
# --> 944         raise DimensionalityError(src, dst, src_dim, dst_dim)
#     946 # Here src and dst have only multiplicative units left. Thus we can
#     947 # convert with a factor.
#
# DimensionalityError: Cannot convert from 'dimensionless' (dimensionless) to 'hectogram' ([mass])
#
# During handling of the above exception, another exception occurred:
#
# DimensionalityError                       Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Convert food quantities to FDC units
# ----> 2 df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#       4 # Now may want to filter df by time or place--need to get a unique set of food names.
#       5 df['FDC Price'] = df['Price']/df['FDC Quantity']
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:8740, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8729 from pandas.core.apply import frame_apply
#    8731 op = frame_apply(
#    8732     self,
#    8733     func=func,
#    (...)
#    8738     kwargs=kwargs,
#    8739 )
# -> 8740 return op.apply()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py:688, in FrameApply.apply(self)
#     685 elif self.raw:
#     686     return self.apply_raw()
# --> 688 return self.apply_standard()
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py:812, in FrameApply.apply_standard(self)
#     811 def apply_standard(self):
# --> 812     results, res_index = self.apply_series_generator()
#     814     # wrap results
#     815     return self.wrap_results(results, res_index)
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/apply.py:828, in FrameApply.apply_series_generator(self)
#     825 with option_context("mode.chained_assignment", None):
#     826     for i, v in enumerate(series_gen):
#     827         # ignore SettingWithCopy here in case the user mutates
# --> 828         results[i] = self.f(v)
#     829         if isinstance(results[i], ABCSeries):
#     830             # If we have a view on v, we need to make a copy because
#     831             #  series_generator will swap out the underlying data
#     832             results[i] = results[i].copy(deep=False)
#
# Cell In[35], line 2, in <lambda>(x)
#       1 # Convert food quantities to FDC units
# ----> 2 df['FDC Quantity'] = df[['Quantity','Units']].T.apply(lambda x : fdc.units(x['Quantity'],x['Units']))
#       4 # Now may want to filter df by time or place--need to get a unique set of food names.
#       5 df['FDC Price'] = df['Price']/df['FDC Quantity']
#
# File /opt/conda/lib/python3.9/site-packages/fooddatacentral/fooddatacentral.py:119, in units(q, u, ureg)
#     117     return x.to(ureg.hectogram)
#     118 except DimensionalityError:
# --> 119     return x.to(ureg.deciliter)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/quantity.py:522, in PlainQuantity.to(self, other, *contexts, **ctx_kwargs)
#     505 """Return PlainQuantity rescaled to different units.
#     506
#     507 Parameters
#    (...)
#     518 pint.PlainQuantity
#     519 """
#     520 other = to_units_container(other, self._REGISTRY)
# --> 522 magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     524 return self.__class__(magnitude, other)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/quantity.py:471, in PlainQuantity._convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     468     with self._REGISTRY.context(*contexts, **ctx_kwargs):
#     469         return self._REGISTRY.convert(self._magnitude, self._units, other)
# --> 471 return self._REGISTRY.convert(self._magnitude, self._units, other)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/registry.py:911, in PlainRegistry.convert(self, value, src, dst, inplace)
#     908 if src == dst:
#     909     return value
# --> 911 return self._convert(value, src, dst, inplace)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/context/registry.py:393, in ContextRegistry._convert(self, value, src, dst, inplace)
#     389             src = self._active_ctx.transform(a, b, self, src)
#     391         value, src = src._magnitude, src._units
# --> 393 return super()._convert(value, src, dst, inplace)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/nonmultiplicative/registry.py:206, in NonMultiplicativeRegistry._convert(self, value, src, dst, inplace)
#     201     raise DimensionalityError(
#     202         src, dst, extra_msg=f" - In destination units, {ex}"
#     203     )
#     205 if not (src_offset_unit or dst_offset_unit):
# --> 206     return super()._convert(value, src, dst, inplace)
#     208 src_dim = self._get_dimensionality(src)
#     209 dst_dim = self._get_dimensionality(dst)
#
# File /opt/conda/lib/python3.9/site-packages/pint/facets/plain/registry.py:944, in PlainRegistry._convert(self, value, src, dst, inplace, check_dimensionality)
#     941     # If the source and destination dimensionality are different,
#     942     # then the conversion cannot be performed.
#     943     if src_dim != dst_dim:
# --> 944         raise DimensionalityError(src, dst, src_dim, dst_dim)
#     946 # Here src and dst have only multiplicative units left. Thus we can
#     947 # convert with a factor.
#     948 factor, _ = self._get_root_units(src / dst)
#
# DimensionalityError: Cannot convert from 'dimensionless' (dimensionless) to 'deciliter' ([length] ** 3)

# %%
Prices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Prices
#
# NameError: name 'Prices' is not defined
